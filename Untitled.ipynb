# %%
import pandas as pd
import numpy as np
#from aspect import aspect_extract

# %%
text = "the game is ."
AE = aspect_extract()
A = AE.aspect_extraction(text)

# %%
A
# Out:
# [[('game', 'fun', '_', True), ('game', 'cool', '_', True)]]

# %% [markdown]
# ## games

# %%
adj_mod = pd.read_csv('resource_paper/adjective-modifiers.csv', names=['adverb','weight'], header=None)
adj_mod.set_index('adverb', inplace = True)
adj_mod.head()
# Out:
#             weight
# adverb
# above            2
# absolutely       2
# abundantly       2
# acutely          2
# amazingly        2

# %%
aspect_voc =pd.read_csv('resource_paper/aspects_videogames.csv', names=['noun'], header=None)
aspect_voc.index.name = 'aspect'
aspect_voc.head()
# Out:
#                   noun
# aspect
# art_style   appearance
# art_style  appearances
# art_style    art style
# art_style   art styles
# art_style    art-style

# %%
opinion_lexicon = pd.read_csv('resource_paper/lexicon_videogames.csv', names=['aspect', 'adj','polarity'], header=None)
opinion_lexicon.set_index('adj', inplace = True)
opinion_lexicon.head()
# Out:
#            aspect  polarity
# adj
# guest   art_style         0
# basic   art_style        -1
# visual  art_style         0
# bold    art_style         0
# shaded  art_style        -1

# %%
opinion_lexicon.aspect.nunique()
# Out:
# 19

# %%
aspect_annot = pd.read_csv('resource_paper/annotations_voc_amazon_Video_Games_5.txt', sep='\t', names=['userID','itemID','noun','aspect', 'adjective','is_negated','adjective_modifier'], header=None)
#aspect_annot.reset_index(inplace=True)
#aspect_annot.rename(columns={"index":"userID"},inplace = True)
aspect_annot.head(10)
# Out:
#            userID      itemID      noun    aspect    adjective  is_negated  \
# 0  A2HD75EMZR8QLN  0700099867      rate     price         sure           0
# 1  A3UR8NLLY1ZHCX  0700099867    voices    sounds         even           0
# 2  A1DLMTOTHQ4AST  0700099867  graphics  graphics  magnificent           0
# 3  A1DLMTOTHQ4AST  0700099867  gameplay  gameplay    excellent           0
# 4  A1DLMTOTHQ4AST  0700099867  graphics  graphics         good           0
# 5  A1DLMTOTHQ4AST  0700099867  graphics  graphics       enough           0
# 6  A1DLMTOTHQ4AST  0700099867  graphics  graphics       higher           0
# 7  A1DLMTOTHQ4AST  0700099867  graphics  graphics    framerate           0
# 8  A361M14PU2GUEG  0700099867  graphics  graphics      perfect           0
# 9  A2UTRVO4FDCBH6  0700099867  graphics  graphics      overall           0
#
#   adjective_modifier
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN

# %%
aspect_annot.shape
# Out:
# (451579, 8)

# %%
a = aspect_annot.head(1000)

# %%
from sentiment import sentiment_orientation
so = sentiment_orientation()
result = so.sentiment_calc(a, opinion_lexicon, adj_mod)
result.head()
# Out:
# /home/amifaraj/Documents/Projects/fall-19/WE_reserach/sentiment.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   aspect_annot['SO']=''
# /home/amifaraj/Documents/Projects/fall-19/WE_reserach/sentiment.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   new_df['adj_polarity'][index] = self.get_padj(new_df, opinion_lexicon, index)
# /home/amifaraj/Documents/Projects/fall-19/WE_reserach/sentiment.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   new_df['adj_mod'][index] = self.get_wmod(new_df, adj_mod, index)
# /home/amifaraj/Documents/Projects/fall-19/WE_reserach/sentiment.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   new_df['is_affirmative'][index] = self.get_waff(new_df,index)
# /home/amifaraj/anaconda3/lib/python3.7/site-packages/pyarrow/pandas_compat.py:114: FutureWarning: A future version of pandas will default to `skipna=True`. To silence this warning, pass `skipna=True|False` explicitly.
#   result = infer_dtype(pandas_collection)
#      aspect    adjective  is_negated adjective_modifier SO adj_polarity  \
# 0     price         sure           0                NaN  0            0
# 1    sounds         even           0                NaN  0            0
# 2  graphics  magnificent           0                NaN  0            0
# 3  gameplay    excellent           0                NaN  0            0
# 4  graphics         good           0                NaN  0            0
#
#   adj_mod is_affirmative
# 0       1              1
# 1       1              1
# 2       1              1
# 3       1              1
# 4       1              1

# %%
import spacy 
import neuralcoref 
nlp = spacy.load('en') 
neuralcoref.add_to_pipe(nlp)

# %%
doc=nlp('I have a dog. I love her.')

# %%
doc._.coref_clusters
# Out:
# [a dog: [a dog, her]]

# %% [markdown]
# corenlp for python: https://stanfordnlp.github.io/stanfordnlp/
#
# models for treebank: https://stanfordnlp.github.io/stanfordnlp/models.html
#
# coref: https://github.com/huggingface/neuralcoref
#
# https://github.com/huggingface/neuralcoref/issues/189
#
# http://ir.ii.uam.es/aspects/

# %%
aspect_annot.head(20)
# Out:
#             userID      itemID        noun         aspect    adjective  \
# 0   A2HD75EMZR8QLN  0700099867        rate          price         sure
# 1   A3UR8NLLY1ZHCX  0700099867      voices         sounds         even
# 2   A1DLMTOTHQ4AST  0700099867    graphics       graphics  magnificent
# 3   A1DLMTOTHQ4AST  0700099867    gameplay       gameplay    excellent
# 4   A1DLMTOTHQ4AST  0700099867    graphics       graphics         good
# 5   A1DLMTOTHQ4AST  0700099867    graphics       graphics       enough
# 6   A1DLMTOTHQ4AST  0700099867    graphics       graphics       higher
# 7   A1DLMTOTHQ4AST  0700099867    graphics       graphics    framerate
# 8   A361M14PU2GUEG  0700099867    graphics       graphics      perfect
# 9   A2UTRVO4FDCBH6  0700099867    graphics       graphics      overall
# 10  A2UTRVO4FDCBH6  0700099867    graphics       graphics         good
# 11  A2UTRVO4FDCBH6  0700099867  controller       controls     steering
# 12  A2UTRVO4FDCBH6  0700099867    keyboard       controls   impossible
# 13   AN3YYDZAS3O1Y  0700099867    graphics       graphics         good
# 14   AN3YYDZAS3O1Y  0700099867    graphics       graphics     gorgeous
# 15  A38NXTZUFB1O2K  0700099867       modes  customization        great
# 16  A38NXTZUFB1O2K  0700099867    graphics       graphics        great
# 17  A38NXTZUFB1O2K  0700099867    gameplay       gameplay    excellent
# 18  A38NXTZUFB1O2K  0700099867  difficulty     difficulty       casual
# 19  A38NXTZUFB1O2K  0700099867      issues          theme   whatsoever
#
#     is_negated adjective_modifier SO
# 0            0                NaN
# 1            0                NaN
# 2            0                NaN
# 3            0                NaN
# 4            0                NaN
# 5            0                NaN
# 6            0                NaN
# 7            0                NaN
# 8            0                NaN
# 9            0                NaN
# 10           0               very
# 11           0                NaN
# 12           0             almost
# 13           0                NaN
# 14           0         absolutely
# 15           0                NaN
# 16           0                NaN
# 17           0                NaN
# 18           0                NaN
# 19           1                NaN

# %%
import json
import pandas as pd
import numpy as np
df = pd.read_json('resource_paper/reviews_Video_Games_5.json', lines=True)
df.head()
# Out:
#          asin  helpful  overall  \
# 0  0700099867  [8, 12]        1
# 1  0700099867   [0, 0]        4
# 2  0700099867   [0, 0]        1
# 3  0700099867  [7, 10]        3
# 4  0700099867   [2, 2]        4
#
#                                           reviewText   reviewTime  \
# 0  Installing the game was a struggle (because of...   07 9, 2012
# 1  If you like rally cars get this game you will ...  06 30, 2013
# 2  1st shipment received a book instead of the ga...  06 28, 2014
# 3  I got this version instead of the PS3 version,...  09 14, 2011
# 4  I had Dirt 2 on Xbox 360 and it was an okay ga...  06 14, 2011
#
#        reviewerID                        reviewerName  \
# 0  A2HD75EMZR8QLN                                 123
# 1  A3UR8NLLY1ZHCX  Alejandro Henao "Electronic Junky"
# 2  A1INA0F5CWW3J4          Amazon Shopper "Mr.Repsol"
# 3  A1DLMTOTHQ4AST                            ampgreen
# 4  A361M14PU2GUEG        Angry Ryan "Ryan A. Forrest"
#
#                                            summary  unixReviewTime
# 0         Pay to unlock content? I don't think so.      1341792000
# 1                                  Good rally game      1372550400
# 2                                        Wrong key      1403913600
# 3  awesome game, if it did not crash frequently !!      1315958400
# 4                                           DIRT 3      1308009600

# %%
az_videogames = df.drop(columns=['helpful','overall','reviewTime','reviewerName','summary','unixReviewTime'])

# %%
az_videogames.rename(columns={'asin':'itemID', 'reviewerID':'userID', 'reviewText':'reviews' },inplace=True)
az_videogames.head()
# Out:
#        itemID                                            reviews  \
# 0  0700099867  Installing the game was a struggle (because of...
# 1  0700099867  If you like rally cars get this game you will ...
# 2  0700099867  1st shipment received a book instead of the ga...
# 3  0700099867  I got this version instead of the PS3 version,...
# 4  0700099867  I had Dirt 2 on Xbox 360 and it was an okay ga...
#
#            userID
# 0  A2HD75EMZR8QLN
# 1  A3UR8NLLY1ZHCX
# 2  A1INA0F5CWW3J4
# 3  A1DLMTOTHQ4AST
# 4  A361M14PU2GUEG

# %%
az_videogames.shape
# Out:
# (231780, 3)

# %%
sample_data = az_videogames.head(10)

# %%
import stanfordnlp
import pandas as pd
nlp = stanfordnlp.Pipeline(lang='en', treebank ='en_gum')
doc = nlp('The multiplayer isnot the best but it works just ok')
dependency = doc.sentences[0].dependencies
depTable = pd.DataFrame(dependency, columns=['gov', 'rel', 'dep'])
depTable
# Out:
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/home/amifaraj/stanfordnlp_resources/en_gum_models/en_gum_tokenizer.pt', 'lang': 'en', 'shorthand': 'en_gum', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/home/amifaraj/stanfordnlp_resources/en_gum_models/en_gum_tagger.pt', 'pretrain_path': '/home/amifaraj/stanfordnlp_resources/en_gum_models/en_gum.pretrain.pt', 'lang': 'en', 'shorthand': 'en_gum', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': '/home/amifaraj/stanfordnlp_resources/en_gum_models/en_gum_lemmatizer.pt', 'lang': 'en', 'shorthand': 'en_gum', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: depparse
# With settings:
# {'model_path': '/home/amifaraj/stanfordnlp_resources/en_gum_models/en_gum_parser.pt', 'pretrain_path': '/home/amifaraj/stanfordnlp_resources/en_gum_models/en_gum.pretrain.pt', 'lang': 'en', 'shorthand': 'en_gum', 'mode': 'predict'}
# Done loading processors!
# ---
#                                                  gov     rel  \
# 0  <Word index=2;text=multiplayer;lemma=multiplay...     det
# 1  <Word index=3;text=isnot;lemma=isnot;upos=VERB...   nsubj
# 2                           <Word index=0;text=ROOT>    root
# 3  <Word index=5;text=best;lemma=good;upos=ADJ;xp...     det
# 4  <Word index=3;text=isnot;lemma=isnot;upos=VERB...     obj
# 5  <Word index=8;text=works;lemma=work;upos=VERB;...      cc
# 6  <Word index=8;text=works;lemma=work;upos=VERB;...   nsubj
# 7  <Word index=3;text=isnot;lemma=isnot;upos=VERB...    conj
# 8  <Word index=10;text=ok;lemma=ok;upos=ADJ;xpos=...  advmod
# 9  <Word index=8;text=works;lemma=work;upos=VERB;...   xcomp
#
#                                                  dep
# 0  <Word index=1;text=The;lemma=the;upos=DET;xpos...
# 1  <Word index=2;text=multiplayer;lemma=multiplay...
# 2  <Word index=3;text=isnot;lemma=isnot;upos=VERB...
# 3  <Word index=4;text=the;lemma=the;upos=DET;xpos...
# 4  <Word index=5;text=best;lemma=good;upos=ADJ;xp...
# 5  <Word index=6;text=but;lemma=but;upos=CCONJ;xp...
# 6  <Word index=7;text=it;lemma=it;upos=PRON;xpos=...
# 7  <Word index=8;text=works;lemma=work;upos=VERB;...
# 8  <Word index=9;text=just;lemma=just;upos=ADV;xp...
# 9  <Word index=10;text=ok;lemma=ok;upos=ADJ;xpos=...

# %%
from nltk import sent_tokenize
#sentences = sent_tokenize(az_videogames.reviews[1])
sentences = az_videogames.reviews[1].split('.')
from nltk.tokenize import word_tokenize

def process(text):
    tokens = word_tokenize(text)
    processed =[]
    for word in tokens:
        word = word.replace("n't", "not")
        word = word.replace("'", "")
        word = word.replace("#", "")
        word = word.replace(";", "")
        word = word.replace("&", "and")
        word = word.replace("'", "o")
        processed.append(word)
    processed = ' '.join(map(str, processed))    
    return processed

# %%
from aspect import aspect_extract
AE = aspect_extract()
A=[]
for txt in sentences:
    proc_txt = process(txt)
    print(proc_txt)
    res = AE.aspect_extraction(proc_txt)
    print(res)
    A.append(res)
# Out:
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/home/amifaraj/stanfordnlp_resources/en_gum_models/en_gum_tokenizer.pt', 'lang': 'en', 'shorthand': 'en_gum', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/home/amifaraj/stanfordnlp_resources/en_gum_models/en_gum_tagger.pt', 'pretrain_path': '/home/amifaraj/stanfordnlp_resources/en_gum_models/en_gum.pretrain.pt', 'lang': 'en', 'shorthand': 'en_gum', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': '/home/amifaraj/stanfordnlp_resources/en_gum_models/en_gum_lemmatizer.pt', 'lang': 'en', 'shorthand': 'en_gum', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: depparse
# With settings:
# {'model_path': '/home/amifaraj/stanfordnlp_resources/en_gum_models/en_gum_parser.pt', 'pretrain_path': '/home/amifaraj/stanfordnlp_resources/en_gum_models/en_gum.pretrain.pt', 'lang': 'en', 'shorthand': 'en_gum', 'mode': 'predict'}
# Done loading processors!
# ---
# If you like rally cars get this game you will have fun
# [[('car', 'rally', '_', True)]]
# It is more oriented to and  34  European market and  34  since here in America there is not a huge rally fan party
# [[('@card@', 'European', '_', True)], [('party', 'huge', '_', True)], [('party', 'rally', '_', True)]]
# Music it is very European and even the voices from the game very and  34  English and  34  accent
# [[('Music', 'European', 'very', True), ('Music', 'voice', 'very', True)]]
# The multiplayer is not the best but it works just ok
# [[('multiplayer', 'good', '_', False)], [('it', 'ok', 'just', True)]]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-9-b0ecfe5ca3ac> in <module>()
#       5     proc_txt = process(txt)
#       6     print(proc_txt)
# ----> 7     res = AE.aspect_extraction(proc_txt)
#       8     print(res)
#       9     A.append(res)
#
# ~/Documents/Projects/fall-19/WE_reserach/aspect.py in aspect_extraction(self, text)
#     184     def aspect_extraction(self, text):
#     185
# --> 186         df = self.extractDependencies(text)
#     187         df = self.makeNeg(df, 'dep')
#     188
#
# ~/Documents/Projects/fall-19/WE_reserach/aspect.py in extractDependencies(self, sentence)
#      26
#      27     def extractDependencies(self, sentence):
# ---> 28         doc = nlp(sentence)
#      29         dependency = doc.sentences[0].dependencies
#      30         depTable = pd.DataFrame(dependency, columns=['gov', 'rel', 'dep'])
#
# ~/anaconda3/lib/python3.7/site-packages/stanfordnlp/pipeline/core.py in __call__(self, doc)
#     174         if isinstance(doc, str) or isinstance(doc, list):
#     175             doc = Document(doc)
# --> 176         self.process(doc)
#     177         return doc
#
# ~/anaconda3/lib/python3.7/site-packages/stanfordnlp/pipeline/core.py in process(self, doc)
#     168         for processor_name in self.processor_names:
#     169             if self.processors[processor_name] is not None:
# --> 170                 self.processors[processor_name].process(doc)
#     171         doc.load_annotations()
#     172
#
# ~/anaconda3/lib/python3.7/site-packages/stanfordnlp/pipeline/tokenize_processor.py in process(self, doc)
#      73                                    self.config.get('max_seqlen', TokenizeProcessor.MAX_SEQ_LENGTH_DEFAULT))
#      74                 # set conll file for doc
# ---> 75                 doc.conll_file = conll.CoNLLFile(input_str=conll_output_string.getvalue())
#      76
#
# ~/anaconda3/lib/python3.7/site-packages/stanfordnlp/models/common/conll.py in __init__(self, filename, input_str, ignore_gapping)
#      18             raise Exception("File not found at: " + filename)
#      19         if filename is None:
# ---> 20             assert input_str is not None and len(input_str) > 0
#      21             self._file = input_str
#      22             self._from_str = True
#
# AssertionError:

# %%
A
# Out:
# [[[('car', 'rally', '_', True)]],
#  [[('@card@', 'European', '_', True)],
#   [('party', 'huge', '_', True)],
#   [('party', 'rally', '_', True)]],
#  [[('Music', 'European', 'very', True), ('Music', 'voice', 'very', True)]],
#  [[('multiplayer', 'good', '_', False)], [('it', 'ok', 'just', True)]]]
